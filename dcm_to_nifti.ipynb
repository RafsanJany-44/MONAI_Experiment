# %%
# !pip install dicom2nifti
# Out:
# ...
#      ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#      ---------------------------- ----------- 30.7/43.6 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 43.6/43.6 kB 538.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      - -------------------------------------- 0.1/2.0 MB 2.2 MB/s eta 0:00:01
#      --- ------------------------------------ 0.2/2.0 MB 2.4 MB/s eta 0:00:01
#      --------- ------------------------------ 0.5/2.0 MB 3.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.5/2.0 MB 3.3 MB/s eta 0:00:01
#      --------------------- ------------------ 1.1/2.0 MB 4.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.1/2.0 MB 3.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.4/2.0 MB 4.6 MB/s eta 0:00:01
#      --------------------------------- ------ 1.7/2.0 MB 4.6 MB/s eta 0:00:01
# ...

# %%
import dicom2nifti as dn
import os

# %%
path = 'C:/Users/RAZER/Downloads/CT_Medical_Images/dicom_dir/*'

path_out = "C:/Users/RAZER/Downloads/CT_Medical_Images/nifti_dir"

# %%
dn.dicom_series_to_nifti(path, os.path.join(path_out,"hello.nii.gz"))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 dn.dicom_series_to_nifti(path, os.path.join(path_out,"hello.nii.gz"))
#
# File ~\anaconda3\envs\Mamba\lib\site-packages\dicom2nifti\convert_dicom.py:73, in dicom_series_to_nifti(original_dicom_directory, output_file, reorient_nifti)
#      71 try:
#      72     dicom_directory = os.path.join(temp_directory, 'dicom')
# ---> 73     shutil.copytree(original_dicom_directory, dicom_directory)
#      75     dicom_input = common.read_dicom_directory(dicom_directory)
#      77     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#
# File ~\anaconda3\envs\Mamba\lib\shutil.py:566, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     527 """Recursively copy a directory tree and return the destination directory.
#     528
# ...

# %%
path = 'C:/Users/RAZER/Downloads/CT_Medical_Images/dicom_dir/'

# %%
dicom2nifti.convert_directory(path, ".")
# Out:
# At least 3 slices are needed for correct conversion
# ---------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\RAZER\anaconda3\envs\Mamba\lib\site-packages\dicom2nifti\convert_dir.py", line 85, in convert_directory
#     convert_dicom.dicom_array_to_nifti(dicom_input, nifti_file, reorient)
#   File "C:\Users\RAZER\anaconda3\envs\Mamba\lib\site-packages\dicom2nifti\convert_dicom.py", line 117, in dicom_array_to_nifti
#     results = convert_generic.dicom_to_nifti(dicom_list, output_file)
#   File "C:\Users\RAZER\anaconda3\envs\Mamba\lib\site-packages\dicom2nifti\convert_generic.py", line 112, in dicom_to_nifti
#     common.validate_slicecount(dicom_input)
#   File "C:\Users\RAZER\anaconda3\envs\Mamba\lib\site-packages\dicom2nifti\common.py", line 1018, in validate_slicecount
#     raise ConversionValidationError('TOO_FEW_SLICES/LOCALIZER')
# dicom2nifti.exceptions.ConversionValidationError: TOO_FEW_SLICES/LOCALIZER
# ...

# %%
nifti = nib.load('201_t2w_tse.nii.gz')
